# %% [markdown]
# ### **5. Song Recommender Test**
#
# - Build a simple Python function that, given a song, looks up its cluster and recommends other songs in the same cluster.
# - Optionally, filter by **Hot 100** songs only (because sometimes you just want the hits, right?).
# - Validate your recommendations with your friends or classmates to ensure it feels spot-on. 🔥

# %%
import pandas as pd

# %%
songs_df = pd.read_csv('../data/clean/7_clustered_dataset.csv')

# %%
def recommend_songs(song_name, songs_df):
    """
    Recommends songs that are in the same cluster as the given song.
    
    Parameters:
    - song_name: The name of the song you want recommendations for.
    - songs_df: DataFrame containing song data (including 'cluster' column).
    
    Returns:
    - A list of recommended songs.
    """
    
    song_row = songs_df[songs_df['title'] == song_name] #check if song exists
    if song_row.empty:
        return f"Song '{song_name}' not found in the database."
    
    song_cluster = song_row['cluster'].values[0]    # check cluster label
    
    same_cluster_songs = songs_df[songs_df['cluster'] == song_cluster]  # get songs in the same cluster
    
    recommended_songs = same_cluster_songs[same_cluster_songs['title'] != song_name]['title'].tolist()  # get recommended songs
    
    return recommended_songs if recommended_songs else 'No other songs found in the same cluster.'

# %%
song_name = "Bennie"  # Replace with the song name you're testing
recommendations = recommend_songs(song_name, songs_df)

print(f"Recommended songs for '{song_name}':")
print(recommendations)
# Out:
# Recommended songs for 'Bennie':
# ['Howells Delight', 'Zip-a-Dee-Doo-Dah (From "Song of the South")', 'Parto em Terras Distantes', 'Life Force', 'Blood Round Dance Song', 'Playa del sous-sol', 'Fascinating Rhythm (Remastered 2014)', 'Grand frère - BOF "Princesses"', 'Calm Da Seas', "Rainbow Country (Knee Deep's Club Mix)", 'Strange Things', 'Washington Post - 1998 Digital Remaster', "I'll Wait For You Dear", 'Wohär dr Wind wäiht', 'Putt Jhatt Da Gulabi Phull Varga', 'Forever More (Francois K & Eric Kupper Vocal Mix)', 'Sehnsuchtsexpress', 'Birch', 'Killer', 'From My Hands', 'Mit Lust tritt ich an diesen Tanz', "I'm In The Mood For Love", 'Cup Horn - Original Mix', 'Vitamina', 'A Veces Hablo De Ti', 'Faithkeeper - Part 1', 'Collecting Dust', 'You Had Me from Hello', 'You Must Do Your Best Tonight / I Represent/Animal Crackers', 'De Paris Un Caballero', 'La rue du babouin (feat. Maurane)', 'Big Bounce', 'Portobello Lass', 'Trumansburg Whistle', 'Sporable', 'The Earth Isnt Humming', 'Champion', 'King Jesus Is My Captain', 'Red Sky', 'Shouther to Shouther - 1917 recording', 'Virtuosite Musette - Polka', 'Michelle', 'Grown & Sexy', "Wolf In Sheep's Clothing", 'Pussy Hole', 'El Cumbanchero', 'El Divertido', 'Blackwood Moth', 'Never Alone', 'Sporco Ma Distinto', 'Elle Et Moi', 'Camisa Amarela', 'Keep the Circle Around', 'Birth Of The Falls', 'La Rosa', 'Our Lady of Fatima (Original Mix)', 'Banda Yango', 'The Anthem', 'Clavelitos', 'Opening', 'Do You See the Light? (Looking For) (feat. Niki Haris) (7" Edit)', 'Save My Soul - Gabriel & Dresden Bootleg Mix', 'Joy to the World', 'Road To Bali: The Merry-Go-Runaround', 'Canción De Títeres', 'Loup Garou', 'So Many Reasons - Homecoming Classics Vol. 11 Album Version', 'The Croppy Boy', 'Play The Part', 'A história do incêndio do jequitibá de Carangola', 'Elementro - Original Mix', 'Strangers In The House - From “Casper” Soundtrack', 'A.C.A.B. - Live', 'Song For Paul', 'Alma de Metal', 'La Fruta Bomba', 'Na Primeira Manhã', 'Carol of the Bells', 'IV', 'Jesus, Lover Of My Soul', 'Fall Line - Live feat. Matt Costa', "It's Good To Know Jesus", 'Things You Do To Me', 'O For a Thousand Tongues', "Kaloobafak (I'm Confessin' That I Love You)", '我有今日 - 2022 Live', 'Washes Over Me - Wamdue09 Remix Extended', 'Jag Vet En Dejlig Rosa', 'Make It Up', 'Le Roi A Fait Battre Tambour', 'Never Alone', '新不了情', 'Fortunate Fool', 'Tu Quieres Volver', "Duh Duh Da - Joe Smooth's Mix", "Pete's Crusade", "You're Nobody Till Somebody Loves You", 'Forgive Me - Medium Key Performance Track With Background Vocals', "I'll Pray For You", 'Schauet Her!', 'La chanson des genêts', 'Ay Nare Nare', 'Ya Basta', 'Sommarens sista mås', 'General Chariot Corp.', 'Dontchaletmecatchya', 'Je suis le passeur du printemps', 'Song For Stephin Merritt', 'Mis Calles de Arena', "Kathleen's Song / Ray Lynch", "L'etang chimerique", 'El Capiro', 'Si Te Dicen Por Ahi', 'Pickled Heads', 'Beauty Queen (12" Original Mix)', 'Revelations By John', 'On The Road To Emmaus', '離家出走', 'Cuando Quieres Tu', 'Djessy', 'Times Like These - Club Mix', 'Aquel Amor', 'Indita Mia', 'Pocket Calculator - 2009 Remaster', 'Die Art von Mann', 'Over You (Orchestral Version)', 'Avec lui', 'The Lord Will Go Before You', 'Vennette', 'Procession', 'Escape From The City - Original Motion Picture Soundtrack', 'Reach For The Ground', 'Existing Alone', 'I Know a Man', 'Hot Tamale Baby', 'Everything I Desire', 'Raza Cristalera', "L'horizon chimérique", "Only A Look - Glad You're Here Album Version", 'Ubik the Breakz (feat. Martin Bettinghaus) - Radio Mix', 'Lioraras', 'Mercy', 'Kick Jump - Part Jump', 'Toot Toot Dixie Bound', 'Smile', 'There Is a Way', 'If My Baby', '戀愛天才', 'Whosoever Will', 'Because Of You', 'Letters to Norway', 'By Faith I Can Touch Him Now', 'Wait On the Lord', '紀念品', 'Introduction', 'Oriza Eh', 'Thresh Hold', 'Fat Tianne', 'Houston Anthem', 'Til The Storm Passes By', 'Curiosity', 'La Matanza', 'Juggernaut', "I Used to Love You (But It's All Over Now)", 'Firedance', 'The Keys', 'New Detroit ...
